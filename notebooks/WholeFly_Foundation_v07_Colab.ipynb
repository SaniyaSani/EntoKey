# %% [markdown]
# # TaxaLens v0.7 — Whole-Fly Foundation 🪰
# No anatomy masks required. BIOSCAN + iNaturalist + GBIF + DiSSCo → DINOv3 whole-fly embeddings → hierarchical ID + retrieval.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/SaniyaSani/TaxaLens.git || true
# %cd TaxaLens
# !pip -q install -r requirements-foundation.txt

# %% [markdown]
# ## 1. Check source files
# Edit `configs/sources_wholefly_v07.example.json` paths if your data live on Drive.

# %%
# !python scripts/source_status_v07.py --config configs/sources_wholefly_v07.example.json

# %% [markdown]
# ## 2. Cache DINOv3
# Small is the default Colab/T4 backbone.

# %%
# !python scripts/cache_backbone.py --model facebook/dinov3-vits16-pretrain-lvd1689m

# %% [markdown]
# ## 3. Build / verify master manifest
# If your normalized source manifests are ready, assemble and deduplicate them.

# %%
# !python scripts/prepare_corpus.py --config configs/sources_wholefly_v07.example.json --stage assemble

# %% [markdown]
# ## 4. Plan the 100k whole-fly corpus

# %%
MASTER='data/corpus_v07/master_manifest.parquet'
# !python scripts/run_wholefly_v07.py --master-manifest $MASTER --stage plan

# %% [markdown]
# ## 5. Embed resumable shards
# Use `--max-shards 2` or `3` per session if you want short, safe Colab runs. Finished shards are skipped.

# %%
# !python scripts/run_wholefly_v07.py --master-manifest $MASTER --stage embed --max-shards 2

# %% [markdown]
# ## 6. Train after all shards are complete

# %%
# !python scripts/run_wholefly_v07.py --master-manifest $MASTER --stage train

# %% [markdown]
# The training report includes overall metrics, per-source metrics, BIOSCAN source-split metrics where available, and top confusion pairs. Use those errors to decide whether a targeted head/wing/morphology module is worth building.
